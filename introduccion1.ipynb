# %% [markdown]
# # ITQ
# # PAO 2025-2026
# **Nombre:** *Elvis Pachacama* <br>
# **Fecha:** *07/01/2026*

# %% [markdown]
# # Introducción a Python
# Python es un lenguaje de programacón de alto nivel <br>
# Tambien python me pertmite desarrollar aplicacines de escritorio y web <br>

# %%
# Aquí va un comentario
#system.out.println("Hola mundo");
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# https://github.com/ElvisDavis/machine2026nocturno/blob/main/introduccion.ipynb
